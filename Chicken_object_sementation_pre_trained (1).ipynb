# %% [markdown]
# **Segmentation using YOLOv11**

# %%
# !pip install Ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 kB 10.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model=YOLO("yolo11n-seg.pt")
results=model("17.jpg")
results[0].show()
# Out:
# image 1/1 /content/17.jpg: 448x640 1 bird, 596.5ms
# Speed: 25.8ms preprocess, 596.5ms inference, 57.0ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=612x408>

# %%
from ultralytics import YOLO
model=YOLO("yolo11n-seg.pt")
results=model("19.jpg")
results[0].show()
# Out:
# image 1/1 /content/19.jpg: 448x640 9 birds, 255.3ms
# Speed: 4.4ms preprocess, 255.3ms inference, 27.2ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=612x408>
